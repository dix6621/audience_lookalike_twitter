# %%
import pandas as pd
import datetime
import time
import json
import functions_twitter

# Read input.csv with interested twitter_username.
users_data_df = pd.read_csv(f'output_0/twitter_summary_df_0.tsv', sep = '\t', usecols = ['username', 'id', 'public_metrics.following_count'])

# Read list of secrets. Due to rate limit, multiple twitter developer accounts are recommended.
secrets_pool = pd.read_csv('twitter_dev_secrets.csv', index_col = False)
bearer_tokens = list(secrets_pool['bearer_token'])

# Filter twitter_usernames with non-zero following_count
users_data_df_nonzero = users_data_df[(users_data_df['public_metrics.following_count'] > 0)]

# Rank twitter_usernams by following_count in descending order
users_data_df_nonzero.sort_values('public_metrics.following_count', ascending = True, inplace = True)
users_data_df_nonzero.reset_index(drop=True, inplace=True)

# Calculate total users and following included in analysis
total_users_count = len(users_data_df_nonzero)
total_following = users_data_df_nonzero['public_metrics.following_count'].sum()

total_bearer_token_count = min(20, len(bearer_tokens)) # Max cap is at 20 bearer_tokens
request_left = 15 # Request limit for GET /2/users/:id/following is 15 requests per 15-minute window (app auth)
following_per_batch = 1000 # per 15minutes
rate_of_req_hrly = total_bearer_token_count*request_left*following_per_batch*4

est_time_req_hr = total_following/rate_of_req_hrly

text = f"Total number of Twitter Developer Accounts = {total_bearer_token_count}\nTotal number of Twitter Usernames = {total_users_count}\nTotal number of following = {total_following}\nEstimated time required for analysis = {est_time_req_hr:.2f} hrs"
#open text file
text_file = open(f"output_0/analytics_notice.txt", "w")
#write string to file
text_file.write(text)
#close file
text_file.close()

bearer_tokens_catridge = bearer_tokens.copy()
bearer_token = bearer_tokens_catridge.pop(0)
# request_left = 15 # Request limit for GET /2/users/:id/following is 15 requests per 15-minute window (app auth)
rate_limit_reset_time = time.mktime(datetime.datetime.now().timetuple()) + 1000 # timestamp when bearer_token_catridge restarted

users_following = []
error_log = []

# %%
# for index, row in users_data_df_nonzero[623:].iterrows(): 
    user_following = []
    origin_id = row['id']
    origin_username = row['username']
    nxt_page = True
    nxt_token = ''
    while nxt_page:
        print(f'{index} - {origin_username} | {len(bearer_tokens_catridge)} - {request_left}')
        if request_left > 0:
            request, request_left = functions_twitter.twitter_get_following_by_users(origin_id, nxt_token, bearer_token)
            if request.status_code == 200:
                try:
                    request_json = request.json()
                    user_following += request_json['data']
                    request_meta = request_json['meta']
                    if 'next_token' in request_meta.keys(): # There are more following under username
                        nxt_page = True # Continue with while loop
                        nxt_token = f'&pagination_token={request_meta["next_token"]}' # Save pagination token
                    else:
                        nxt_page = False # Stop iteration of current username
                except KeyError:
                    print(f'{origin_username} - Might be a private account. No access allowed.')
                    error_detail = {'error' : f'Might be a private account. No access allowed.', 'username' : origin_username}
                    error_log.append(error_detail)
                    nxt_page = False # Stop iteration of current username
            else: # Requests failed. Did not get full list of following of username
                print(f'{origin_username} - Incomplete run. Did not finish extracting all followers')
                error_detail = {'error' : f'Incomplete run. Did not finish extracting all following', 'username' : origin_username}
                error_log.append(error_detail)
                nxt_page = False # Stop iteration of current username
        else:
            request_reset_unixtime = float(request.headers['x-rate-limit-reset']) # timestamp when the request limit for bearer token is expected to reset.
            rate_limit_reset_time = min(request_reset_unixtime,rate_limit_reset_time)
            bearer_tokens_catridge, bearer_token, request_left, rate_limit_reset_time = functions_twitter.catridge_reset(rate_limit_reset_time, bearer_tokens_catridge, bearer_tokens, 15)
    if len(user_following) == 0:
        continue
    else:
        user_following = [dict(item, **{'origin_username':origin_username}) for item in user_following]
        users_following += user_following
# Out:
# 623 - ELebedowicz | 0 - 0
# 623 - ELebedowicz | 23 - 15
# 624 - lain_capital | 23 - 14
# 625 - atomicnuc | 23 - 14
# 626 - khaledrolexx | 23 - 13
# 627 - ArrafiqFadhil | 23 - 13
# 628 - BTCchuanzhang | 23 - 12
# 629 - Flight60854279 | 23 - 11
# 630 - 0x5414 | 23 - 12
# 631 - neatnodes | 23 - 11
# 632 - Barbara46851049 | 23 - 10
# 633 - Melissa22468661 | 23 - 10
# 634 - saram65682605 | 23 - 9
# 635 - WesthMorten | 23 - 8
# 636 - Andy95046183 | 23 - 7
# 637 - MaltaDanniel | 23 - 9
# 638 - O_PrimoCripto | 23 - 8
# 639 - ngaxuan8 | 23 - 6
# 640 - yancheva_viki | 23 - 7
# 641 - Jcrypticblok | 23 - 5
# 642 - hiaxi27 | 23 - 4
# 643 - IlgiCizmeci | 23 - 6
# 644 - GVidansh | 23 - 3
# 645 - OliverJ29049432 | 23 - 5
# 646 - Jkjobiy | 23 - 4
# 647 - Brittan49892315 | 23 - 3
# 648 - Alvin23838260 | 23 - 2
# 649 - thulasi240691 | 23 - 2
# 650 - Bal91180315Al | 23 - 1
# 651 - 0xfootball2022 | 23 - 1
# 652 - VaultsPro | 23 - 0
# 652 - VaultsPro | 22 - 15
# 653 - LevyMwandamah | 22 - 14
# 654 - LuckyGamEr369 | 22 - 14
# 655 - NganKha2 | 22 - 13
# 656 - KoltonJalen | 22 - 12
# 657 - Mary61203490 | 22 - 13
# 658 - 85moving | 22 - 11
# 659 - DonovanGay12 | 22 - 10
# 660 - KeepitSusty | 22 - 12
# 661 - AM98547383 | 22 - 9
# 662 - waagneerrman | 22 - 8
# 663 - MukukaErick | 22 - 7
# 664 - ghostffgr1 | 22 - 11
# 665 - todorov_leonid | 22 - 10
# 666 - ManoloEti | 22 - 6
# 667 - ornk_t | 22 - 5
# 668 - RanarianR | 22 - 4
# 669 - hunterdrop23 | 22 - 9
# 670 - EmilyPerr | 22 - 8
# 671 - SmolCock_ | 22 - 3
# 672 - kane854735461 | 22 - 7
# 673 - couraud_nicolas | 22 - 6
# 674 - arbicalls | 22 - 5
# 675 - BetaniaEricka | 22 - 2
# 676 - PluribusUnum0 | 22 - 4
# 677 - Naymara04424156 | 22 - 1
# 678 - DaoGazelle | 22 - 3
# 679 - Lhoo520 | 22 - 2
# 680 - luisgmsalmeida | 22 - 0
# 680 - luisgmsalmeida | 21 - 15
# 681 - 0xYutsa | 21 - 14
# 682 - KatL31797341 | 21 - 14
# 683 - PatrickGeertsen | 21 - 13
# 684 - wg06765655 | 21 - 12
# 685 - AptosMintz | 21 - 11
# 686 - IstokCeric | 21 - 10
# 687 - Guest2000123 | 21 - 13
# 688 - YtiPh | 21 - 12
# 689 - welke_van | 21 - 11
# 690 - turtmcgurt2k | 21 - 9
# 691 - Holockop | 21 - 8
# 692 - A45777539 | 21 - 10
# 693 - chris52111 | 21 - 9
# 694 - GGpcpJ8eqdC6yYm | 21 - 7
# 695 - ODLPLATOKEN | 21 - 8
# 696 - CryptoCoach17 | 21 - 6
# 697 - hngnph689 | 21 - 7
# 698 - KhoiNhanKN | 21 - 5
# 699 - xlef18 | 21 - 4
# 700 - Jaxx2204 | 21 - 3
# 701 - RosePrince007 | 21 - 2
# 702 - MarXdotcom | 21 - 1
# 703 - BelieversGmx | 21 - 6
# 704 - winniem15266308 | 21 - 5
# 705 - frances51964073 | 21 - 0
# 705 - frances51964073 | 20 - 15
# 706 - TrungDo312 | 20 - 14
# 707 - KeyboardW4 | 20 - 14
# 708 - LadangRok | 20 - 13
# 709 - whale818 | 20 - 13
# 710 - 0x3813 | 20 - 12
# 711 - Arto27529959 | 20 - 11
# 712 - frederi45758808 | 20 - 12
# 713 - MohammadNaghiP4 | 20 - 10
# 714 - Solange65220880 | 20 - 11
# 715 - 0xClocky | 20 - 10
# 716 - tt_rrrppp | 20 - 9
# 717 - LaureColleaux | 20 - 8
# 718 - vanlyndocong | 20 - 9
# 719 - keyrich15 | 20 - 7
# 720 - AimeeAl93392131 | 20 - 8
# 721 - FishbaitFinance | 20 - 6
# 722 - sompasm | 20 - 5
# 723 - danisio002 | 20 - 4
# 724 - Eskimo62450460 | 20 - 7
# 725 - CobieXiv | 20 - 6
# 726 - Joppa42662246 | 20 - 3
# 727 - ramin326446491 | 20 - 5
# 728 - Rypto2 | 20 - 4
# 729 - Vitalikscrip | 20 - 3
# 730 - SmolYuhhhh | 20 - 2
# 731 - LeonorC90277549 | 20 - 2
# 732 - l6wAVv0Z9eaHDPS | 20 - 1
# 733 - kuowis | 20 - 1
# 734 - QuyetDao203 | 20 - 0
# 734 - QuyetDao203 | 19 - 15
# 735 - Trongbeo992 | 19 - 14
# 736 - saltykovdg | 19 - 14
# 737 - EugeniaBorgmey1 | 19 - 13
# 738 - lumo202210 | 19 - 12
# 739 - Zavlakov1993 | 19 - 11
# 740 - massymaz | 19 - 10
# 741 - yaxixi77 | 19 - 9
# 742 - gopluslabs | 19 - 13
# 743 - Sahil53551576 | 19 - 12
# 744 - di16_dila | 19 - 11
# 745 - BitcoV | 19 - 10
# 746 - idriss_eth | 19 - 8
# 747 - ZifengMai3 | 19 - 7
# 748 - corinne89052362 | 19 - 6
# 749 - DefiAnons | 19 - 5
# 750 - Scout35763733 | 19 - 4
# 751 - MillionerXxX | 19 - 9
# 752 - Jellylandland | 19 - 8
# 753 - MacMartell2 | 19 - 7
# 754 - Krisko5556 | 19 - 3
# 755 - cdqigl33ubpooe | 19 - 2
# 756 - HamzaNa14135064 | 19 - 1
# 757 - Mohamed24982538 | 19 - 0
# 757 - Mohamed24982538 | 18 - 15
# 758 - bullbearycrypto | 18 - 14
# 759 - GmxLeaderboard | 18 - 14
# 760 - namtvh0602 | 18 - 13
# 761 - MarcoT68801981 | 18 - 12
# 762 - jwpark92280967 | 18 - 13
# 763 - caartmann | 18 - 11
# 764 - Y6KELWyogZAH3hM | 18 - 10
# 765 - LabeenI | 18 - 9
# 766 - JKf884 | 18 - 12
# 767 - ShaunTan_0x | 18 - 11
# 768 - Hero41220634 | 18 - 8
# 769 - EdgerunnerK | 18 - 10
# 770 - jumbo_bj | 18 - 7
# 771 - Sonali49479481 | 18 - 6
# 772 - Arti_kizz | 18 - 9
# 773 - testetetstts | 18 - 8
# 774 - duskrdt | 18 - 5
# 775 - 0x97028 | 18 - 7
# 776 - DiamondKzt | 18 - 4
# 777 - BraveryCapital2 | 18 - 6
# 778 - Anthony_C01_ | 18 - 5
# 779 - P1bobby1 | 18 - 4
# 780 - NancyBr72461705 | 18 - 3
# 781 - w3s_AnPha3 | 18 - 3
# 782 - Liujiay24547254 | 18 - 2
# 783 - AptosDucks | 18 - 1
# 784 - DebraSiler20 | 18 - 0
# 784 - DebraSiler20 | 17 - 15
# 785 - rugshield1 | 17 - 14
# 786 - Leaddao | 17 - 13
# 787 - ivacryptography | 17 - 12
# 788 - abdulhannan161 | 17 - 11
# 789 - nnyn46743802 | 17 - 10
# 790 - mtstkgms2 | 17 - 14
# 791 - mmrmatch | 17 - 13
# 792 - Ikuz4k | 17 - 9
# 793 - VBlacktea | 17 - 12
# 794 - Shay56256211 | 17 - 8
# 795 - QaisarB484 | 17 - 11
# 796 - Maruf80942447 | 17 - 7
# 797 - mryu852 | 17 - 6
# 798 - sekzek2 | 17 - 10
# 799 - Wepullcrypto | 17 - 5
# 800 - cryto_c | 17 - 4
# 801 - MindyYo88761603 | 17 - 3
# 802 - fongericsun | 17 - 9
# 803 - ZeroDelta18 | 17 - 8
# 804 - catalinrusu999 | 17 - 7
# 805 - Eth4ia | 17 - 2
# 806 - ErickJo79458047 | 17 - 1
# 807 - williamrise13 | 17 - 0
# 807 - williamrise13 | 16 - 15
# 808 - grallin | 16 - 14
# 809 - Toddfu3 | 16 - 13
# 810 - Erkan45894790 | 16 - 12
# 811 - TraderDesigner | 16 - 11
# 812 - CavellB7 | 16 - 14
# 813 - tamahsum | 16 - 13
# 814 - Kashiimura3D | 16 - 10
# 815 - WinemakerGregor | 16 - 9
# 816 - matress74 | 16 - 12
# 817 - SakaiVault | 16 - 8
# 818 - AlexBotek | 16 - 11
# 819 - HABERCI270 | 16 - 10
# 820 - tdau234 | 16 - 9
# 821 - PlebInvestor | 16 - 7
# 822 - freezeincorp | 16 - 8
# 823 - PaulSch02713432 | 16 - 6
# 824 - Nathani37817244 | 16 - 5
# 825 - junglefreak351 | 16 - 7
# 826 - dat8811 | 16 - 4
# 827 - m_raket | 16 - 3
# 828 - Brandon09038105 | 16 - 6
# 829 - forestc97105410 | 16 - 5
# 830 - DylanEarl14 | 16 - 4
# 831 - Jamalshahkh | 16 - 3
# 832 - LindstromArto | 16 - 2
# 833 - stantonsylve056 | 16 - 2
# 834 - Elias_Moreno_69 | 16 - 1
# 835 - Antonitus0 | 16 - 0
# 835 - Antonitus0 | 15 - 15
# 836 - KhcTrung6 | 15 - 14
# 837 - FuroProtocol | 15 - 14
# 838 - duobleasc | 15 - 13
# 839 - zhangdi195 | 15 - 12
# 840 - zhangme843 | 15 - 13
# 841 - Jason949596631 | 15 - 12
# 842 - SejdiuVehbi | 15 - 11
# 843 - lgksajl | 15 - 10
# 844 - krishaj1983 | 15 - 11
# 845 - lining33089826 | 15 - 10
# 846 - probesui22 | 15 - 9
# 847 - merichbeach7 | 15 - 8
# 848 - Billi36529567 | 15 - 7
# 849 - n_wfgomez | 15 - 6
# 850 - YH21093405 | 15 - 5
# 851 - dao_wallet | 15 - 9
# 852 - XSimon_16 | 15 - 8
# 853 - Rekaul | 15 - 7
# 854 - Fhimamehdi | 15 - 6
# 855 - noones26126334 | 15 - 5
# 856 - Amazashiba | 15 - 4
# 857 - hghinson | 15 - 4
# 858 - ddddcry | 15 - 3
# 859 - Pawnmaster5 | 15 - 2
# 860 - jarken408 | 15 - 1
# 861 - Gmbb0x | 15 - 0
# 861 - Gmbb0x | 14 - 15
# 862 - JonathanRhodus | 14 - 14
# 863 - NutellaEnFila | 14 - 14
# 864 - Svetlana_Hess72 | 14 - 13
# 865 - 10worksmart | 14 - 13
# 866 - B60X6 | 14 - 12
# 867 - Alfrid65780677 | 14 - 11
# 868 - Samorahamanyan1 | 14 - 12
# 869 - TylerMo03560687 | 14 - 10
# 870 - ArbitrumAlpha | 14 - 11
# 871 - Norrona22 | 14 - 10
# 872 - hilton_id | 14 - 9
# 873 - Olaf_4519 | 14 - 9
# 874 - dengzhi69 | 14 - 8
# 875 - 0xdefiplug | 14 - 8
# 876 - InddE | 14 - 7
# 877 - mesho637 | 14 - 6
# 878 - Leri7788 | 14 - 5
# 879 - steamwoodl | 14 - 4
# 880 - AbigayleRussel4 | 14 - 7
# 881 - ypec4xsmor1si | 14 - 3
# 882 - Garry78363442 | 14 - 6
# 883 - crveck5450544 | 14 - 2
# 884 - jialeruan2001 | 14 - 5
# 885 - LiliaGa18789377 | 14 - 4
# 886 - blladeboris | 14 - 1
# 887 - VnhfVvf | 14 - 3
# 888 - zhongyuwang7 | 14 - 2
# 889 - rubik2713 | 14 - 1
# 890 - Gasmann8 | 14 - 0
# 890 - Gasmann8 | 13 - 15
# 891 - GcxVjfx | 13 - 14
# 892 - cnc_ktotheoni | 13 - 13
# 893 - smpsns_fam | 13 - 12
# 894 - esternam111 | 13 - 11
# 895 - AylaBonilla | 13 - 14
# 896 - 0x52796 | 13 - 13
# 897 - DoNhung14563210 | 13 - 12
# 898 - JorikGreven | 13 - 11
# 899 - MiloWyatt3 | 13 - 10
# 900 - ThaoTha55235519 | 13 - 10
# 901 - MeeChar2 | 13 - 9
# 902 - Bo45230963 | 13 - 8
# 903 - sajjadhussainsd | 13 - 7
# 904 - simongoeskrypto | 13 - 6
# 905 - ronniee327 | 13 - 5
# 906 - KadirDE35110814 | 13 - 9
# 907 - Pashchenko711 | 13 - 4
# 908 - Istvan85581774 | 13 - 8
# 909 - OioraTuang | 13 - 7
# 910 - six85488105 | 13 - 6
# 911 - LordoftheSkies4 | 13 - 5
# {origin_username} - Might be a private account. No access allowed.
# 912 - MatDei2 | 13 - 4
# 913 - ginbilily | 13 - 3
# {origin_username} - Might be a private account. No access allowed.
# 914 - Cryptovenus69 | 13 - 3
# 915 - PSotskov | 13 - 2
# 916 - EAsankojoev | 13 - 1
# 917 - Jeremaglio | 13 - 2
# 918 - zgui6703 | 13 - 1
# 919 - HannahUnderwood | 13 - 0
# 919 - HannahUnderwood | 12 - 15
# 920 - GxhxSuu | 12 - 14
# 921 - UhcfFh | 12 - 13
# 922 - SilverSilverGal | 12 - 14
# 923 - Rishi1813 | 12 - 13
# 924 - NigelPine | 12 - 12
# 925 - Haider72118019 | 12 - 11
# 926 - GosseRory | 12 - 12
# 927 - richard022220 | 12 - 11
# 928 - Vitorbjanuario | 12 - 10
# 929 - cryptozzle | 12 - 10
# 930 - IathSaith | 12 - 9
# 931 - MarginSafetyV | 12 - 8
# 932 - gmgn6715 | 12 - 9
# 933 - MarcioTheves | 12 - 8
# 934 - Arbitruft | 12 - 7
# 935 - IjazKha03153386 | 12 - 7
# 936 - stavannn | 12 - 6
# 937 - NatalieLattimo4 | 12 - 6
# 938 - StrongStoic | 12 - 5
# 939 - parkfox2 | 12 - 4
# 940 - Clampthelamp | 12 - 5
# 941 - Tungbctt | 12 - 4
# 942 - Juny20566448 | 12 - 3
# 943 - Tom_Noodle_JD | 12 - 3
# 944 - Armin76142990 | 12 - 2
# 945 - BagicsKrisztian | 12 - 2
# 946 - BeEasyBrick | 12 - 1
# 947 - Vaporwa24473842 | 12 - 1
# 948 - 6RINeth | 12 - 0
# 948 - 6RINeth | 11 - 15
# 949 - Miradora76961 | 11 - 14
# 950 - dubresponce | 11 - 14
# 951 - ribeirojulio_ | 11 - 13
# 952 - Tonya04036162 | 11 - 13
# 953 - seunghwan_kwon | 11 - 12
# 954 - blackwireio | 11 - 12
# 955 - johnchengshuo | 11 - 11
# 956 - diallom09725431 | 11 - 10
# 957 - 6Igariok9 | 11 - 11
# 958 - Imjason420 | 11 - 10
# 959 - supplangg2804 | 11 - 9
# 960 - BasicAbsolute | 11 - 8
# {origin_username} - Might be a private account. No access allowed.
# 961 - Michael79659394 | 11 - 7
# 962 - ShayleeFreeman | 11 - 9
# 963 - DeFiBlockIL | 11 - 6
# 964 - gomar_joba | 11 - 5
# 965 - hhy_kunl | 11 - 8
# 966 - FrederikDitlef1 | 11 - 7
# 967 - 2xBp4 | 11 - 6
# 968 - Bajes84 | 11 - 5
# 969 - Gtvrzk | 11 - 4
# 970 - SlurpMcGurk | 11 - 4
# 971 - arbibarbie23 | 11 - 3
# 972 - OmarKaufman2 | 11 - 3
# 973 - ElekoUmukoro | 11 - 2
# 974 - Etoos009 | 11 - 2
# 975 - infinous01 | 11 - 1
# 976 - kk97858513 | 11 - 0
# 976 - kk97858513 | 10 - 15
# 977 - 0Xemi0X | 10 - 14
# 978 - Raulru9 | 10 - 13
# 979 - GangOrcaTy | 10 - 14
# 980 - AlaWaiPaddler | 10 - 12
# 981 - Liliyasamiguli | 10 - 11
# 982 - markus_vitulli | 10 - 13
# 983 - AyhamKhalid10 | 10 - 12
# 984 - rsrch01 | 10 - 10
# 985 - theback34462282 | 10 - 11
# 986 - Gmannnnnnnnn | 10 - 10
# 987 - KajaWeronika | 10 - 9
# 988 - NuccioGroup | 10 - 8
# 989 - Larryarb3Arb | 10 - 9
# 990 - LeaLann39 | 10 - 7
# 991 - emptyledger | 10 - 6
# 992 - DDeniscik | 10 - 8
# 993 - kirlimannnz | 10 - 5
# 994 - nxvywxddxrsbrxh | 10 - 4
# 995 - SaylorBp | 10 - 3
# 996 - Jason_STX | 10 - 2
# 997 - tryintobeactive | 10 - 7
# 998 - v2x2mbtnvr | 10 - 1
# {origin_username} - Might be a private account. No access allowed.
# 999 - Deste16978727 | 10 - 6
# 1000 - leonard37812603 | 10 - 0
# 1000 - leonard37812603 | 9 - 15
# 1001 - minisosoroun | 9 - 14
# 1002 - tmdgus464 | 9 - 14
# 1003 - starfucks_eth | 9 - 13
# 1004 - QuocBaco | 9 - 12
# 1005 - Peter96374045 | 9 - 13
# 1006 - 1Jour1Crypto | 9 - 11
# 1007 - spydcr | 9 - 10
# 1008 - peterpipenipple | 9 - 9
# 1009 - PasicnikOleg | 9 - 8
# 1010 - papacandelo77 | 9 - 7
# 1011 - Chompinatthedip | 9 - 12
# 1012 - GeDonte | 9 - 6
# 1013 - AXL140B | 9 - 11
# 1014 - UmarGuj73852272 | 9 - 5
# 1015 - ohmmi75588264 | 9 - 10
# 1016 - RobinMo70041186 | 9 - 9
# 1017 - TasosFs1 | 9 - 8
# 1018 - FladsonAngeloo | 9 - 4
# 1019 - marcorlin1 | 9 - 7
# 1020 - leyiyoung | 9 - 6
# 1021 - aiwaahq | 9 - 5
# 1022 - AlexisR20184152 | 9 - 3
# 1023 - JeyciNomi | 9 - 2
# 1024 - Fran42798456 | 9 - 4
# 1025 - 0xkloshard | 9 - 1
# 1026 - mchkvitka | 9 - 3
# 1027 - Agapov16Ivan | 9 - 2
# 1028 - eon__genesis | 9 - 0
# 1028 - eon__genesis | 8 - 15
# 1029 - Rahul33620103 | 8 - 14
# 1030 - gang0094 | 8 - 14
# 1031 - JooBati52542332 | 8 - 13
# 1032 - oscar00cryt | 8 - 12
# 1033 - AvijitM098 | 8 - 11
# 1034 - jimmy_putten89 | 8 - 10
# 1035 - ZibiBASZA | 8 - 9
# 1036 - hepphgod | 8 - 13
# 1037 - MrAirforGood | 8 - 12
# 1038 - luciavershich | 8 - 8
# 1039 - qianjin453525 | 8 - 11
# 1040 - DaleDaw94439241 | 8 - 7
# 1041 - KrgiInocencio | 8 - 10
# 1042 - defi_enjoyer_ | 8 - 6
# 1043 - ZhifeiS | 8 - 9
# 1044 - AhuyJlez | 8 - 8
# 1045 - Andresr74x | 8 - 5
# 1046 - HY30449350 | 8 - 7
# 1047 - hhanbckjs123a | 8 - 4
# 1048 - Nelly14189969 | 8 - 3
# 1049 - Maaurose | 8 - 6
# 1050 - __Mahboob__ | 8 - 5
# 1051 - HKnocksville | 8 - 4
# 1052 - Aston3118 | 8 - 2
# 1053 - babrown1974 | 8 - 3
# 1054 - Mrwen51264147 | 8 - 2
# 1055 - CryptoAstrobot | 8 - 1
# 1056 - Akarthi21129380 | 8 - 0
# 1056 - Akarthi21129380 | 7 - 15
# 1057 - crossilviasalt | 7 - 14
# 1058 - crackiddo | 7 - 14
# 1059 - wamered | 7 - 13
# 1060 - ReviewsAmir | 7 - 12
# 1061 - lsmith_alt | 7 - 13
# 1062 - gustaaguiar10 | 7 - 11
# 1063 - VjgfFfc | 7 - 10
# 1064 - martus6767 | 7 - 9
# 1065 - HungDinhThanh1 | 7 - 8
# 1066 - AngelitoCorona3 | 7 - 7
# 1067 - PiotrCzaja10 | 7 - 6
# 1068 - anissmi1 | 7 - 12
# 1069 - Wault_Disney | 7 - 5
# 1070 - Tn1521994 | 7 - 4
# 1071 - damro3030 | 7 - 3
# 1072 - Kacper700p | 7 - 11
# 1073 - PZenovich | 7 - 2
# 1074 - MikMac2021 | 7 - 10
# 1075 - JaneJones616 | 7 - 9
# 1076 - ri_dwight | 7 - 1
# 1077 - LFQueiros | 7 - 8
# 1078 - TheShoppe88 | 7 - 0
# 1078 - TheShoppe88 | 6 - 15
# 1079 - urfabian03 | 6 - 14
# 1080 - FabricioFarlen | 6 - 14
# 1081 - OLEGTheKul | 6 - 13
# 1082 - harmon_reilly | 6 - 13
# 1083 - CarlosF07558951 | 6 - 12
# 1084 - Debbi77111368 | 6 - 12
# 1085 - W_Diegocripto | 6 - 11
# 1086 - gavin_1413 | 6 - 11
# 1087 - LukasNrkvc | 6 - 10
# 1088 - mick_danzig | 6 - 10
# 1089 - ArbitrumToken | 6 - 9
# 1090 - AmedEvenDeferia | 6 - 8
# 1091 - RowenaSmit4 | 6 - 7
# 1092 - NguyenSimChat | 6 - 6
# 1093 - maxwell_valadao | 6 - 5
# 1094 - xiaolaohu1991 | 6 - 4
# 1095 - Braavos_Finance | 6 - 3
# 1096 - luv_t3a | 6 - 2
# 1097 - synswap_xyz | 6 - 9
# 1098 - 0xekko1 | 6 - 8
# 1099 - enock_sabah | 6 - 7
# 1100 - pL29ohpqzoBf4vm | 6 - 1
# 1101 - rabbit_lucia | 6 - 6
# 1102 - xuexuenian | 6 - 5
# 1103 - Vivian9666 | 6 - 0
# 1103 - Vivian9666 | 5 - 15
# 1104 - bznfdx | 5 - 14
# 1105 - PlawgoMariusz | 5 - 14
# 1106 - Lisa20773284 | 5 - 13
# 1107 - AdmanNikol | 5 - 12
# 1108 - MarJime15287077 | 5 - 11
# 1109 - bluechip_boi | 5 - 10
# {origin_username} - Might be a private account. No access allowed.
# 1110 - SadeSykes8 | 5 - 13
# 1111 - marcosaleciode1 | 5 - 9
# 1112 - dudieicjeeac405 | 5 - 8
# {origin_username} - Might be a private account. No access allowed.
# 1113 - DrewCowles17 | 5 - 7
# 1114 - nuklearino | 5 - 6
# 1115 - GallaGioele | 5 - 12
# 1116 - Lat48vc | 5 - 11
# 1117 - evercarlenkrai1 | 5 - 5
# 1118 - nhs1120 | 5 - 10
# 1119 - AlfioMancini | 5 - 9
# 1120 - RafaRydzek | 5 - 4
# 1121 - Cliff_Bur | 5 - 3
# 1122 - AmandaM30890612 | 5 - 2
# 1123 - freeboy6668 | 5 - 8
# 1124 - CarlosM84691101 | 5 - 7
# 1125 - RDanilox | 5 - 1
# 1126 - truongthotb | 5 - 0
# 1126 - truongthotb | 4 - 15
# 1127 - TanyaGupta1902 | 4 - 14
# 1128 - ab72b2335bf9434 | 4 - 13
# 1129 - Quincy32w | 4 - 12
# 1130 - caoziyang1990 | 4 - 11
# 1131 - m_mollik | 4 - 10
# 1132 - Fmotta_ | 4 - 14
# 1133 - ArtemPivnuk | 4 - 13
# 1134 - zniceguy9 | 4 - 12
# 1135 - acosta_kaya | 4 - 11
# 1136 - yuyuracuxo | 4 - 10
# 1137 - AragLahcen | 4 - 9
# 1138 - ArulvelVel | 4 - 9
# 1139 - Omoh26510125 | 4 - 8
# 1140 - xIntern_478 | 4 - 8
# 1141 - Anonymoustonyys | 4 - 7
# 1142 - mfirefour | 4 - 6
# 1143 - AsPgcy | 4 - 5
# 1144 - Avinash_D26 | 4 - 7
# 1145 - FruitYogi | 4 - 6
# 1146 - TrongHo402 | 4 - 5
# 1147 - thutrin20620558 | 4 - 4
# 1148 - mum2juc_c | 4 - 3
# 1149 - Patrici669 | 4 - 2
# 1150 - CsabaMile | 4 - 1
# {origin_username} - Might be a private account. No access allowed.
# 1151 - EmersonAlvesIn1 | 4 - 4
# {origin_username} - Might be a private account. No access allowed.
# 1152 - TerenceR19 | 4 - 3
# 1153 - dxdufxp | 4 - 0
# 1153 - dxdufxp | 3 - 15
# 1154 - Julius_C_Caesar | 3 - 14
# 1155 - longest_movie | 3 - 13
# 1156 - andras_otto | 3 - 12
# 1157 - VesterBuster | 3 - 11
# 1158 - jonatan68173 | 3 - 10
# 1159 - FccfVbhgf | 3 - 14
# 1160 - tao_ree | 3 - 13
# 1161 - Mannylovedunks | 3 - 9
# 1162 - giandolfa | 3 - 12
# 1163 - hkhkcd | 3 - 11
# 1164 - InnovaMaxi | 3 - 10
# 1165 - HHlebovich | 3 - 8
# 1166 - dAppBeast1 | 3 - 7
# 1167 - joh5656 | 3 - 6
# 1168 - dbekweiod | 3 - 9
# 1169 - SebBlair_ | 3 - 5
# 1170 - Jennife2061 | 3 - 4
# 1171 - AhmadDa202 | 3 - 8
# {origin_username} - Might be a private account. No access allowed.
# 1172 - FiorellaTaylor5 | 3 - 7
# 1173 - j0k3r_news | 3 - 6
# 1174 - bankoffuture | 3 - 5
# 1175 - cetinkucakli | 3 - 4
# 1176 - Vibe888888 | 3 - 3
# 1177 - ChooiJon | 3 - 2
# 1178 - ADNANKH82798282 | 3 - 3
# 1179 - yuseonmin12 | 3 - 2
# 1180 - afra3192 | 3 - 1
# 1181 - tam86257853 | 3 - 1
# 1182 - mirza_sifur | 3 - 0
# 1182 - mirza_sifur | 2 - 15
# 1183 - Perakman12 | 2 - 14
# 1184 - TrangLinh_777 | 2 - 14
# 1185 - yudigen7 | 2 - 13
# 1186 - Sergio56743 | 2 - 13
# 1187 - KasperHeerfordt | 2 - 12
# 1188 - TiborHo12554779 | 2 - 12
# 1189 - ZubairK38316913 | 2 - 11
# 1190 - CeFiDeFiLer | 2 - 11
# 1191 - gmxdart | 2 - 10
# 1192 - Patryk80065090 | 2 - 9
# 1193 - Muhamme69300236 | 2 - 8
# 1194 - NguyenHuyPhi88 | 2 - 7
# 1195 - wiratam75528023 | 2 - 6
# 1196 - freee_will | 2 - 10
# 1197 - mev95_eth | 2 - 9
# 1198 - ster63080143 | 2 - 8
# 1199 - airdrops1111111 | 2 - 5
# 1200 - oliveirapele33 | 2 - 4
# 1201 - Hunghoqn | 2 - 7
# 1202 - DiorVd | 2 - 3
# 1203 - wepolynek | 2 - 6
# 1204 - VanioAlmeida7 | 2 - 5
# 1205 - EdsonAn67943171 | 2 - 4
# 1206 - Tom62222719 | 2 - 3
# 1207 - token_duck | 2 - 2
# {origin_username} - Might be a private account. No access allowed.
# 1208 - LuciferVangsaa | 2 - 2
# 1209 - LaminSavel | 2 - 1
# 1210 - Giseleblini | 2 - 0
# 1210 - Giseleblini | 1 - 15
# 1211 - baswho1 | 1 - 14
# 1212 - John790928 | 1 - 13
# 1213 - aptosduckss | 1 - 14
# 1214 - panwenping666 | 1 - 12
# 1215 - dzutokoga | 1 - 11
# 1216 - AptosKangarooz | 1 - 10
# 1217 - ANRYNSY | 1 - 13
# 1218 - isamurat32 | 1 - 9
# 1219 - LucaDoru1 | 1 - 8
# 1220 - adonis_radar | 1 - 7
# 1221 - IvxVegapunk01 | 1 - 6
# 1222 - flint_keit | 1 - 12
# 1223 - Vassi80093603 | 1 - 5
# 1224 - sakkawet | 1 - 11
# 1225 - michaelggre | 1 - 4
# 1226 - IhclabI | 1 - 10
# 1227 - zkVlad | 1 - 9
# 1228 - alkatraztt | 1 - 8
# 1229 - franzbr0482 | 1 - 7
# 1230 - daniseth0 | 1 - 3
# 1231 - bryce_us | 1 - 6
# 1232 - hamburg_joshua | 1 - 5
# 1233 - shepinhui888 | 1 - 2
# 1234 - Edouard_Crypto | 1 - 1
# 1235 - anthonyshen19 | 1 - 4
# 1236 - LordEPF | 1 - 0
# 1236 - LordEPF | 0 - 15
# 1237 - dave00239615 | 0 - 14
# 1238 - ivfKVVzYn2PeHYm | 0 - 14
# 1239 - AAwokojo | 0 - 13
# 1240 - VibrumNetwork | 0 - 13
# 1241 - tsuiclarita89cz | 0 - 12
# {origin_username} - Might be a private account. No access allowed.
# 1242 - NftOniks | 0 - 12
# 1243 - RC06264359 | 0 - 11
# 1244 - StSch55 | 0 - 10
# 1245 - beecollect88 | 0 - 11
# 1246 - Numanat1At | 0 - 9
# 1247 - wangru818412 | 0 - 10
# 1248 - Lewis666888 | 0 - 9
# 1249 - locaizhang | 0 - 8
# 1250 - WalkingOSuntime | 0 - 7
# 1251 - CloakedMuggle | 0 - 8
# 1252 - felipemaster12 | 0 - 6
# 1253 - ethdesc168 | 0 - 5
# 1254 - TradeTheIan | 0 - 7
# 1255 - TheWeb3Saviour | 0 - 4
# 1256 - sadounikav | 0 - 3
# 1257 - Zipple10 | 0 - 2
# 1258 - SemenyukTim | 0 - 1
# 1259 - lowellysse | 0 - 6
# 1260 - JameyHolifield | 0 - 5
# 1261 - Rodrigo61791827 | 0 - 4
# 1262 - napnapgive | 0 - 0
# Bearer Token Catridge reset. Estimated time remaining to restart = 823 seconds.

# %%
users_following_df = pd.DataFrame(users_following)
users_following_df.to_csv('output_0/users_following_df_0.csv')

error_log_df = pd.DataFrame(error_log)
error_log_df.to_csv('output_0/error_log_df_0.csv')
