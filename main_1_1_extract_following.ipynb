# %%
import pandas as pd
import datetime
import time
import json
import functions_twitter

# Read input.csv with interested twitter_username.
users_data_df = pd.read_csv(f'output_0/twitter_summary_df_0.tsv', sep = '\t', usecols = ['username', 'id', 'public_metrics.following_count'])

# Read list of secrets. Due to rate limit, multiple twitter developer accounts are recommended.
secrets_pool = pd.read_csv('twitter_dev_secrets.csv', index_col = False)
bearer_tokens = list(secrets_pool['bearer_token'])

# Filter twitter_usernames with non-zero following_count
users_data_df_nonzero = users_data_df[(users_data_df['public_metrics.following_count'] > 0)]

# Rank twitter_usernams by following_count in descending order
users_data_df_nonzero.sort_values('public_metrics.following_count', ascending = True, inplace = True)
users_data_df_nonzero.reset_index(drop=True, inplace=True)

# Calculate total users and following included in analysis
total_users_count = len(users_data_df_nonzero)
total_following = users_data_df_nonzero['public_metrics.following_count'].sum()

total_bearer_token_count = min(20, len(bearer_tokens)) # Max cap is at 20 bearer_tokens
request_left = 15 # Request limit for GET /2/users/:id/following is 15 requests per 15-minute window (app auth)
following_per_batch = 1000 # per 15minutes
rate_of_req_hrly = total_bearer_token_count*request_left*following_per_batch*4

est_time_req_hr = total_following/rate_of_req_hrly

text = f"Total number of Twitter Developer Accounts = {total_bearer_token_count}\nTotal number of Twitter Usernames = {total_users_count}\nTotal number of following = {total_following}\nEstimated time required for analysis = {est_time_req_hr:.2f} hrs"
#open text file
text_file = open(f"output_0/analytics_notice.txt", "w")
#write string to file
text_file.write(text)
#close file
text_file.close()

bearer_tokens_catridge = bearer_tokens.copy()
bearer_token = bearer_tokens_catridge.pop(0)
# request_left = 15 # Request limit for GET /2/users/:id/following is 15 requests per 15-minute window (app auth)
rate_limit_reset_time = time.mktime(datetime.datetime.now().timetuple()) + 1000 # timestamp when bearer_token_catridge restarted

users_following = []
error_log = []

for index, row in users_data_df_nonzero.iterrows():
    user_following = []
    origin_id = row['id']
    origin_username = row['username']
    nxt_page = True
    nxt_token = ''
    while nxt_page:
        print(f'{index} - {origin_username} | {len(bearer_tokens_catridge)} - {request_left}')
        if request_left > 0:
            request, request_left = functions_twitter.twitter_get_following_by_users(origin_id, nxt_token, bearer_token)
            if request.status_code == 200:
                try:
                    request_json = request.json()
                    user_following += request_json['data']
                    request_meta = request_json['meta']
                    if 'next_token' in request_meta.keys(): # There are more following under username
                        nxt_page = True # Continue with while loop
                        nxt_token = f'&pagination_token={request_meta["next_token"]}' # Save pagination token
                    else:
                        nxt_page = False # Stop iteration of current username
                except KeyError:
                    error_detail = {'error' : f'Might be a private account. No access allowed.', 'username' : origin_username}
                    error_log.append(error_detail)
                    nxt_page = False # Stop iteration of current username
            else: # Requests failed. Did not get full list of following of username
                error_detail = {'error' : f'Incomplete run. Did not finish extracting all following', 'username' : origin_username}
                error_log.append(error_detail)
                nxt_page = False # Stop iteration of current username
        else:
            request_reset_unixtime = float(request.headers['x-rate-limit-reset']) # timestamp when the request limit for bearer token is expected to reset.
            rate_limit_reset_time = min(request_reset_unixtime,rate_limit_reset_time)
            bearer_tokens_catridge, bearer_token, request_left, rate_limit_reset_time = functions_twitter.catridge_reset(rate_limit_reset_time, bearer_tokens_catridge, bearer_tokens, 15)
    if len(user_following) == 0:
        continue
    else:
        user_following = [dict(item, **{'origin_username':origin_username}) for item in user_following]
        users_following += user_following

users_following_df = pd.DataFrame(users_following)
users_following_df.to_csv('output_0/users_following_df_0.csv')

error_log_df = pd.DataFrame(error_log)
error_log_df.to_csv('output_0/error_log_df_0.csv')
# Out:
# /var/folders/f9/bcp0x5q54y92yxm2_zmvffqc0000gn/T/ipykernel_61287/544271735.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_data_df_nonzero.sort_values('public_metrics.following_count', ascending = True, inplace = True)
# 0 - VictorV87691741
# 1 - DonJonRambo
# 2 - stupakvip
# 3 - zkSync01
# 4 - Operskie0
# 5 - AP39056879
# 6 - OleksanderKrav1
# 7 - MedyFede
# 8 - gmx_rekt
# 9 - LukaszZiebaa
# 10 - Bob99161782
# 11 - Infcamtecnologi
# 12 - lorenzocioc
# 13 - ZinhagelM
# 14 - GmxDailyActions
# 15 - itspureduh
# 16 - maks20000906
# 17 - CoinWizard7
# 18 - LucasTorrente8
# 19 - Ciroking99
# 20 - InuArbitrum
# 21 - HNY_Optimism
# 22 - bandimohangoud
# 23 - ElBu34714398
# 24 - KriedemannSven
# 25 - OoijenPeter
# 26 - garcevic_j
# 27 - lucoluc1993
# 28 - Lucianaaraujo07
# 29 - gmxunstakebot
# 30 - KelvinMoronari
# 31 - Kameha_Pools
# 32 - LuizFer2470527
# 33 - Jasspre81383334
# 34 - StacyMa04397816
# 35 - ShamsInayat
# 36 - Vmagalhaes90
# 37 - BasicoFoda
# 38 - dazzsnow
# 39 - MarcosV01810246
# 40 - BlueberryPulse
# 41 - Nils34172202
# 42 - DsvDegen
# 43 - Thx2US
# 44 - Nhat313
# 45 - gmxalerts
# 46 - CryptoYoked
# 47 - NikitaSyzonenko
# 48 - Minhdoa42226205
# 49 - bRawlaphant
# 50 - DavidBa29515829
# 51 - nammyio
# 52 - ViolagoKathy
# 53 - 0xMitu
# 54 - accidental_toad
# 55 - HoodlifeClub
# 56 - ShaunSeah2
# 57 - weiqian05140514
# 58 - Almafa08723628
# 59 - LuceroCruz85
# 60 - PendragonZage
# 61 - FreelegitA
# 62 - gmx2779
# 63 - Rosana72719488
# 64 - 0xgoo2
# 65 - merFida69444113
# 66 - mckee_bradly
# 67 - ch4t32
# 68 - GBlueberryClub
# 69 - Gkouters
# 70 - fld_nico
# 71 - goodboy98956425
# 72 - vlkovk
# 73 - MarcosBraga7777
# 74 - Piccap2
# 75 - Cherry92475224
# 76 - Sternherz22
# 77 - zhiqian_xiao
# 78 - conexaoic7
# 79 - Ariana76438186
# 80 - oxUglyFish
# 81 - RodrigoAlvesDi6
# 82 - TraderXen
# 83 - SandroQuimi
# 84 - throwback54
# 85 - GMXMasTree
# 86 - tomaszgorecki5
# 87 - OpenoceanF
# 88 - ThiagoT20846393
# 89 - Saurav660
# 90 - Sandi38141139
# 91 - doomaniac8
# 92 - AbelardoCarde13
# 93 - PainStreetCap
# 94 - PmpBose
# 95 - e_7884800
# 96 - StardustYield
# 97 - Stephen50197515
# 98 - ayoubbelhaj111
# 99 - DiscoverySicily
# 100 - FelipeM32721815
# 101 - MatosyanVahagn
# 102 - SummerM88256598
# 103 - bitcoinbankr
# 104 - AmospiArbi
# 105 - cryptosawan001
# 106 - RalCharles7
# 107 - IsaacRadiant
# 108 - ProfitMilker
# 109 - LuisAlm86285218
# 110 - JillGuo10
# 111 - NeniSuriani3
# 112 - AvastKeygen
# 113 - CkCalvin8
# 114 - NonFunnyToken
# 115 - ArbitrumCoinPad
# 116 - boras_pyic
# 117 - Da_ApocAlypse03
# 118 - JeanAmon11
# 119 - Valenti63895082
# 120 - 9leojp
# 121 - rhoda5jjhjurez
# 122 - EricKle76562340
# 123 - tolodi76
# 124 - SomeoneBesideMe
# 125 - meme_mfrs
# 126 - AdamLen12
# 127 - AzedineDinotk
# 128 - davex737
# 129 - SiadatAmin
# 130 - NitroYeti
# 131 - KierraHardin18
# 132 - BybitLawrence
# 133 - thecryptodeck
# 134 - kalptekisoz
# 135 - SemaSfinks
# 136 - bbxuanb
# 137 - hotcheekychick
# 138 - niemiec2010
# 139 - KaraNurani
# 140 - m786658
# 141 - aamirmasih001
# 142 - Artem_Frang
# 143 - Pabs3003
# 144 - jamesmurakami9
# 145 - DannySwartz8
# 146 - Alberto86645891
# 147 - LisaWar85707929
# 148 - DelirErtug
# 149 - gugyeongtae2
# 150 - degenimp
# 151 - LaurenH45055781
# 152 - Kornukopia_io
# 153 - sresurya1
# 154 - random375717882
# 155 - Gianluc37022408
# 156 - free_aae
# 157 - owais_it_is
# 158 - Nicksuperstar99
# 159 - NFDudes
# 160 - ivx_fi
# 161 - Najib79642068
# 162 - cleansoberj
# 163 - CieraDixon7
# 164 - hiro0x
# 165 - Chaim84482262
# 166 - shanabhai_patel
# 167 - Endic69
# 168 - esraouter
# 169 - Psycarioo
# 170 - Marlene76022536
# 171 - salamakhini
# 172 - TrumanOliver6
# 173 - Mario62948068
# 174 - CallumH1234
# 175 - aryan14231563
# 176 - niwu3172805
# 177 - kei202201
# 178 - GMXBot
# 179 - kutom24
# 180 - GlennMa82866331
# 181 - BihterBlackshe1
# 182 - Alex89245
# 183 - BevisCarroll4
# 184 - dour_scotsman
# 185 - YOKAISWAP123
# 186 - Mahim1945
# 187 - Ericc44155092
# 188 - thanh1234aa
# 189 - quntac_
# 190 - AB_XKA
# 191 - SnakeeFinance
# 192 - Jhonata37185359
# 193 - BFRBULL
# 194 - BowlesMe
# 195 - Michael93866792
# 196 - JackWil19175653
# 197 - Chandle16710502
# 198 - andre_nelsen
# 199 - Arbi_BlueHole
# 200 - BiFrostBattles
# 201 - KrystianJaroma
# 202 - HARSHTH24918874
# 203 - grbtsmsk48
# 204 - mortredhawke
# 205 - optimismlabs
# 206 - ric_green
# 207 - shishididizai
# 208 - 0xVesper
# 209 - gmx_moderator
# 210 - yngibo1
# 211 - Howard78529830
# 212 - HukudomeN
# 213 - markusds03
# 214 - HillarNate
# 215 - WGarcia09446738
# 216 - zedbrike
# 217 - bcooper102
# 218 - DesensWayne
# 219 - Hirschi1995
# 220 - PavelPe27909844
# 221 - ryanhid23961371
# 222 - Heart330367103
# 223 - 0x9xYz23
# 224 - JooVict46381677
# 225 - CryptoMario18
# 226 - inderdaan
# 227 - CryptoOxala
# 228 - Robert84115904
# 229 - NickTho01330366
# 230 - LuvoArbitrum
# 231 - MetaSHIBAINU_
# 232 - 0xGuapo333
# 233 - happycai168
# 234 - GalaxyWTR
# 235 - billycerm
# 236 - CryptoTrading8
# 237 - 165crypto_Real
# 238 - CarlosGonsaga2
# 239 - thelongfart
# 240 - How_About_No48
# 241 - Gamble28425073
# 242 - PurtovaRita
# 243 - fisuape
# 244 - punkmonk83
# 245 - Wjp961
# 246 - AndriyLev4
# 247 - Tingfuza
# 248 - SBlogerov
# 249 - 5YenDesigner
# 250 - SpreeXV
# 251 - WillGoo45266892
# 252 - camishere3
# 253 - deep_poseidon
# 254 - RandCrypt
# 255 - faggionatto
# 256 - lisheng34539983
# 257 - Tsun_zuuu
# 258 - 1nonlykvn
# 259 - optimum_play
# 260 - SelwynHyland
# 261 - Stanisl06106765
# 262 - ArbiApeClub
# 263 - shillddddd
# 264 - tiagoxrojas
# 265 - VitoSino
# 266 - life_was
# 267 - AbachyMehran
# 268 - AS5556222
# 269 - VinhDan16084557
# 270 - NancyFl75799558
# 271 - Oelorr
# 272 - PerpyFinance
# 273 - Paully99778796
# 274 - jclan0x
# 275 - AloSa94539173
# 276 - LeschFreeman
# 277 - rapperscratch
# 278 - CEmlichheim
# 279 - ffjohn66
# 280 - hangluat2
# 281 - AlgorandUpdate
# 282 - Tobi54478676
# 283 - gang1810
# 284 - CrypticBanter22
# 285 - sbfuck_sbfuck
# 286 - cryptoguysTM
# 287 - AblativeToes
# 288 - Hari65872209
# 289 - Kenhhuuich
# 290 - Tiffany17035807
# 291 - appleosios
# 292 - Ammar51797770
# 293 - HTnhNguyn2
# 294 - casquinhas78
# 295 - MrElien_
# 296 - W416Y
# 297 - SardaridreesOf1
# 298 - panatomic1
# 299 - EricaPa35013195
# 300 - JRHMdFctnpRVNUr
# 301 - FlorianZelling2
# 302 - serjser48585643
# 303 - theanh089
# 304 - OxAries88
# 305 - Dmxdao
# 306 - SshekharPatel
# 307 - viizon
# 308 - ClaudiaMulenex
# 309 - b05463071
# 310 - ENisiotis
# 311 - mancheff
# 312 - ualogyps
# 313 - datalab1
# 314 - johnboybert
# 315 - JanPan16015104
# 316 - __BoTu
# 317 - pkonik2
# 318 - Adavathravi
# 319 - Cynthia22319969
# 320 - Joe9041950241
# 321 - jparsont03
# 322 - delgavax
# 323 - TommyTpage
# 324 - Milyfroo
# 325 - z_ayan786
# 326 - AddyChong3
# 327 - RobRoy10961781
# 328 - MaryCol80547675
# 329 - KristaA79635253
# 330 - 0xSDF
# 331 - YusufKa14731430
# 332 - Michael44089395
# 333 - THsantanaTH
# 334 - arc_kor
# 335 - KnetOlaffsen
# 336 - AlyonaShakina
# 337 - c1_protocol
# 338 - AngelaY66385945
# 339 - Daniell65524028
# 340 - ChungThi15
# 341 - mhuthiest
# 342 - johnson_helder
# 343 - Popol53131564
# 344 - Rizkiudin01
# 345 - BvNxgOwWCfAk89Y
# 346 - coindexbot
# 347 - nectareumxyz
# 348 - HaleyJo69681461
# 349 - NftGoddam
# 350 - nh200112
# 351 - jonathanyuen
# 352 - MR_MAN_001
# 353 - Cloudengineer5
# 354 - zxcvbnm27511761
# 355 - corriauxhotmai1
# 356 - AndrejA27724148
# 357 - Hoang_Hai6666
# 358 - Christioomer
# 359 - Luluquestion
# 360 - RyanVic86120304
# 361 - 12ENV
# 362 - Kaique80613606
# 363 - hien1913
# 364 - CraigPa14687138
# 365 - Jennife04237164
# 366 - dtj5179
# 367 - MaxCheh0504
# 368 - NNA96978399
# 369 - ngakhantoff
# 370 - Kathryn27029846
# 371 - souyeintensive
# 372 - TreyAna09822693
# 373 - Musallamali1234
# 374 - Mars21923
# 375 - BonnieLoveless9
# 376 - Scary701
# 377 - LaurenM96272106
# 378 - eduardo_jose26
# 379 - YZemeti
# 380 - vish6500
# 381 - btrncng2
# 382 - ggmn6195
# 383 - Daniell64924066
# 384 - bilobangg
# 385 - tranquykhoaqc
# 386 - AnthonyPolkin10
# 387 - HeptaCapital
# 388 - yigit_gencel
# 389 - OxOtaku
# 390 - NewgateTaio
# 391 - william74669891
# 392 - aytoilesurterre
# 393 - PAL_000000
# 394 - skrowemalf
# 395 - Chisomcrypto
# 396 - BrianOa30050508
# 397 - MinhTrungPhm13
# 398 - OriUngar
# 399 - liiiilad
# 400 - William80139161
# 401 - albal04005271
# 402 - CenHungg
# 403 - ronnakamoto
# 404 - Mike21781578
# 405 - ardev777
# 406 - B0z3y
# 407 - Aurelia76131
# 408 - GCOINSWISS
# 409 - Mellifsone
# 410 - phyzer222
# 411 - taurusloans
# 412 - Spyke46S
# 413 - smollFloppa
# 414 - DeogllashazK
# 415 - Christi71960651
# 416 - LoriTho99816969
# 417 - DKamanskij
# 418 - MariaPo64199303
# 419 - NanceePalen9151
# 420 - DavidTachera
# 421 - Guillau01732426
# 422 - MoneyF0X
# 423 - SammyTark
# 424 - snnguyn57290855
# 425 - Nam06776952
# 426 - hereyrar
# 427 - MaryHarog
# 428 - Piccolo_man
# 429 - Annette24217297
# 430 - JonasDybdal7
# 431 - DonDefiETH
# 432 - uryang_88
# 433 - Sehun41492043
# 434 - CosmosGyoza
# 435 - BurkeWil
# 436 - 1212_loc
# 437 - TranNgo75953710
# 438 - rashadcrypto
# 439 - sijin330
# 440 - ntthuong1991
# 441 - daddychill3131
# 442 - downs_laci
# 443 - HuongGiang1404
# 444 - hodl_like
# 445 - BirjuPa06830290
# 446 - delimaleandro2
# 447 - rhudlerfc9t
# 448 - thebaldeagle601
# 449 - 0xNeptune_
# 450 - airdrophunterni
# 451 - Mantequuillaa
# 452 - brahimK64230618
# 453 - gooloogulu7
# 454 - CalmBuddha1
# 455 - binhw5
# 456 - Hibiki30year
# 457 - amaris71808900
# 458 - eye_seen7
# 459 - MDippro
# 460 - laurensaine
# 461 - LPh38589341
# 462 - LeQuang45899013
# 463 - yumayei_scrip
# 464 - mrjohnstone789
# 465 - Linh188B
# 466 - lightingforlee
# 467 - rafaelm06062019
# 468 - Shannon16987281
# 469 - dzhal2023
# 470 - gmxcn
# 471 - muxi70643010
# 472 - Bryan99446303
# 473 - goblintrum
# 474 - yadi_muhram
# 475 - Dinner86
# 476 - timeblocksnft
# 477 - JoeD34855845
# 478 - kornthebuidler
# 479 - luca76772170
# 480 - anhtooi
# 481 - Binanceyk
# 482 - Crystal52908049
# 483 - FunnyWorkHumor
# 484 - DanMetamask
# 485 - Michell34762321
# 486 - Ivan09087535
# 487 - LisaPut50417058
# 488 - nmcduvogu
# 489 - Marissa84588899
# 490 - AdisS267
# 491 - SahirulKhandak1
# 492 - Roberto34251998
# 493 - Salesuleiman
# 494 - mmotkina
# 495 - Pegasuspow
# 496 - gmxman2
# 497 - James05811849
# 498 - KhoaFL210
# 499 - KupermanDouglas
# 500 - Adel46032041
# 501 - Frosty99942319
# 502 - CryptoRocky3
# 503 - WhiteCliff19
# 504 - nftxv
# 505 - NFTBuildd
# 506 - paulsam2105
# 507 - xc4p3
# 508 - aridrop1771
# 509 - Ronnies07786609
# 510 - arbisled
# 511 - referminator
# 512 - gabrieluk1987
# 513 - MuhammetKalins4
# 514 - Kai3a90
# 515 - KTesarewicz
# 516 - sarrot7
# 517 - DaedalusKnows
# 518 - AroundTime11
# 519 - zzy85710245
# 520 - defibanker1
# 521 - mellowmeout132
# 522 - AkmalFikri6
# 523 - SebastianeHutt
# 524 - savioaalves
# 525 - AleksandrLyf
# 526 - cryptoleclere
# 527 - InarLisovsky
# 528 - las_yua
# 529 - Mont_Virtua
# 530 - ChrisSD81204456
# 531 - xiaD50338
# 532 - VoltGijoe
# 533 - PanodaF
# 534 - Kravvad1
# 535 - adoptmeone
# 536 - bonnie_farke
# 537 - POORHAPPINESS1
# 538 - Farrell18308444
# 539 - bart_fi
# 540 - SarahBo04406808
# 541 - StacyGu86547187
# 542 - Gecileia2011
# 543 - jingzhe21403761
# 544 - Cu3NDT
# 545 - RobertM51556
# 546 - liu_reki
# 547 - o6morok
# 548 - sabrin47144667
# 549 - _Nyceria
# 550 - AGirlInCrypto_
# 551 - a1StakeSource
# 552 - AfamKha70800601
# 553 - SarvarSulajman1
# 554 - BBennasy1990
# 555 - SnookerArb
# 556 - bernie36262
# 557 - KDelgba
# 558 - StefanJosimov2
# 559 - Pirat_Jack777
# 560 - Maxxximumown
# 561 - SpidersilkFi
# 562 - leandro88025144
# 563 - acadinool
# 564 - ArbitrumLeak
# 565 - MeklyshPetro
# 566 - 2sProje
# 567 - sAshok05483502
# 568 - MCT54890722
# 569 - GLECapital
# 570 - NkhuwaWatson
# 571 - llamabee1
# 572 - chenmen98326792
# 573 - VinsonWang
# 574 - Nadiah94462162
# 575 - Mehmet297481141
# 576 - Fairminded435
# 577 - kmyselff20
# 578 - IgorCripto
# 579 - LukaSchoofs
# 580 - VasilinaNenaev1
# 581 - AvinAvinash6
# 582 - cotoc15
# 583 - Pawe24572829
# 584 - AndrejSestakov
# 585 - CEssenziali
# 586 - emelia39713464
# 587 - nicolas_couraud
# 588 - Beachshack40
# 589 - VincentYoo3
# 590 - Waxirkhan01001
# 591 - KatieJa95207465
# 592 - PeterK__1
# 593 - mrcryptogurug
# 594 - 0x_sng
# 595 - ThomasGiani
# 596 - Lando_do_do
# 597 - johny000moo
# 598 - EmrullahUgrlu6
# 599 - kovakr0
# 600 - amorchu5
# 601 - BusinessPlugs
# 602 - StoanovStanimi1
# 603 - MitchellManthey
# 604 - huuphuc012016
# 605 - 6nb7s9mrnr
# 606 - MorganD50449509
# 607 - liqfinance
# 608 - BernieBermudezx
# 609 - AleksPROV235
# 610 - ChappeRaphaele
# 611 - basavegowda22
# 612 - 5ylar1
# 613 - Josuedi2
# 614 - ArvaultDM
# Bearer Token Catridge reset. Estimated time remaining to restart = 633 seconds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/dicksonlai/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/main_1_1_extract_following.ipynb Cell 1 in <cell line: 48>()
#      <a href='vscode-notebook-cell:/Users/dicksonlai/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/main_1_1_extract_following.ipynb#W2sZmlsZQ%3D%3D?line=76'>77</a>         request_reset_unixtime = float(request.headers['x-rate-limit-reset']) # timestamp when the request limit for bearer token is expected to reset.
#      <a href='vscode-notebook-cell:/Users/dicksonlai/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/main_1_1_extract_following.ipynb#W2sZmlsZQ%3D%3D?line=77'>78</a>         rate_limit_reset_time = min(request_reset_unixtime,rate_limit_reset_time)
# ---> <a href='vscode-notebook-cell:/Users/dicksonlai/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/main_1_1_extract_following.ipynb#W2sZmlsZQ%3D%3D?line=78'>79</a>         bearer_tokens_catridge, bearer_token, request_left, rate_limit_reset_time = functions_twitter.catridge_reset(rate_limit_reset_time, bearer_tokens_catridge, bearer_tokens, 15)
#      <a href='vscode-notebook-cell:/Users/dicksonlai/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/main_1_1_extract_following.ipynb#W2sZmlsZQ%3D%3D?line=79'>80</a> if len(user_following) == 0:
#      <a href='vscode-notebook-cell:/Users/dicksonlai/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/main_1_1_extract_following.ipynb#W2sZmlsZQ%3D%3D?line=80'>81</a>     continue
#
# File ~/lfb_spartan/work_file/social_analytics/ecosystem_extraction/engine_room_v3/functions_twitter.py:50, in catridge_reset(rate_limit_reset_time, bearer_tokens_catridge, bearer_tokens, request_left)
#      48         rest_duration = rate_limit_reset_time - time.mktime(datetime.datetime.now().timetuple()) + (5*len(bearer_tokens_catridge))
#      49         print(f'Bearer Token Catridge reset. Estimated time remaining to restart = {rest_duration:.0f} seconds.')
# ---> 50         time.sleep(rest_duration)
#      51         rate_limit_reset_time = time.mktime(datetime.datetime.now().timetuple()) + 1000
#      52 return bearer_tokens_catridge, bearer_token, request_left, rate_limit_reset_time
#
# KeyboardInterrupt:

# %%
users_following_df
# Out:
#                     id                       name         username  \
# 0  1543921444131930113  The Blueberry Podcast 🎙 🫐  TheBerryPodcast
# 1  1491005700750942208          Blueberry Pulse 🫐   BlueberryPulse
# 2  1458678055644368900       GMX Blueberry Club 🫐   GBlueberryClub
#
#   origin_username
# 0          GMX_IO
# 1          GMX_IO
# 2          GMX_IO
